# %%
import pandas as pd
import os
from pathlib import Path

def load_sample_data():
    """Load sample CSV data into the system"""
    data_dir = Path("./data/raw")
    
    # Load all CSV files
    csv_files = {
        "properties": pd.read_csv(data_dir / "properties.csv"),
        "tenants": pd.read_csv(data_dir / "tenants.csv"),
        "maintenance_requests": pd.read_csv(data_dir / "maintenance_requests.csv"),
        "customer_inquiries": pd.read_csv(data_dir / "customer_inquiries.csv")
    }
    
    # Basic statistics
    for name, df in csv_files.items():
        print(f"\n{name.upper()} Data:")
        print(f"Records: {len(df)}")
        print(f"Columns: {list(df.columns)}")
        print(f"Sample:\n{df.head(2)}")
    
    return csv_files

if __name__ == "__main__":
    load_sample_data()
# Out:
# PROPERTIES Data:
# Records: 8
# Columns: ['property_id', 'property_name', 'address', 'city', 'postal_code', 'property_type', 'total_units', 'year_built', 'last_renovation']
# Sample:
#   property_id       property_name              address       city postal_code  \
# 0       P1001  Sunrise Apartments      123 Main Street  Amsterdam      1011AB
# 1       P1002  Harbor View Towers  45 Harbor Boulevard  Rotterdam      3011CD
#
#   property_type  total_units  year_built  last_renovation
# 0   Residential           24        2005             2020
# 1     Mixed-Use           48        2010             2022
#
# TENANTS Data:
# Records: 8
# Columns: ['tenant_id', 'property_id', 'tenant_name', 'email', 'phone', 'lease_start', 'lease_end', 'monthly_rent', 'status']
# Sample:
#   tenant_id property_id   tenant_name                   email      phone  \
# 0      T001       P1001  Jan de Vries   jan.devries@email.com  612345678
# 1      T002       P1001  Maria Garcia  maria.garcia@email.com  623456789
#
#   lease_start   lease_end  monthly_rent  status
# 0  2023-01-01  2024-12-31        1250.0  Active
# 1  2023-03-15  2025-03-14        1350.0  Active
#
# MAINTENANCE_REQUESTS Data:
# Records: 8
# Columns: ['request_id', 'property_id', 'tenant_id', 'issue_date', 'issue_type', 'description', 'priority', 'status', 'assigned_to', 'completion_date']
# Sample:
#       request_id property_id   tenant_id  issue_date  \
# MR001      P1001        T001  2024-01-15    Plumbing
# MR002      P1002        T003  2024-01-18  Electrical
#
#                          issue_type description     priority        status  \
# MR001     Leaking faucet in kitchen      Medium  In Progress    John Smith
# MR002  Flickering lights in hallway        High     Assigned  Emma Johnson
#
#       assigned_to  completion_date
# MR001         NaN              NaN
# MR002         NaN              NaN
#
# CUSTOMER_INQUIRIES Data:
# Records: 8
# Columns: ['inquiry_id', 'date', 'tenant_name', 'property_id', 'inquiry_type', 'message', 'status', 'response_date']
# Sample:
#   inquiry_id        date   tenant_name property_id  inquiry_type  \
# 0     INQ001  2024-01-10  Jan de Vries       P1001  Rent Payment
# 1     INQ002  2024-01-12  Maria Garcia       P1001   Maintenance
#
#                                           message       status response_date
# 0        How can I set up automatic rent payment?     Resolved    2024-01-11
# 1  My neighbor is making excessive noise at night  In Progress           NaN
